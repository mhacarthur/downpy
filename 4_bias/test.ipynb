# %%
import os
import numpy as np
import xarray as xr
import pandas as pd
import seaborn as sns
import geopandas as gpd

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec

# %%
DATA = xr.open_dataset('/home/arturo/Downloads/ITALY_DOWN_ERA5_3h_2002_2023_npix_2_thr_1_acf_mar_genetic_pearson.nc')
DATA
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:  (year: 22, lat: 47, lon: 51, Tr: 6)
# Coordinates:
#   * year     (year) int64 176B 2002 2003 2004 2005 2006 ... 2020 2021 2022 2023
#   * Tr       (Tr) int64 48B 5 10 20 50 100 200
#   * lat      (lat) float64 376B 36.5 36.75 37.0 37.25 ... 47.25 47.5 47.75 48.0
#   * lon      (lon) float64 408B 6.5 6.75 7.0 7.25 7.5 ... 18.25 18.5 18.75 19.0
# Data variables:
#     NYs      (year, lat, lon) float64 422kB ...
#     CYs      (year, lat, lon) float64 422kB ...
#     WYs      (year, lat, lon) float64 422kB ...
#     Mev_s    (Tr, lat, lon) float64 115kB ...
#     NYd      (year, lat, lon) float64 422kB ...
#     CYd      (year, lat, lon) float64 422kB ...
#     WYd      (year, lat, lon) float64 422kB ...
#     Mev_d    (Tr, lat, lon) float64 115kB ...
#     BETA     (lat, lon) float64 19kB ...
#     GAMMA    (lat, lon) float64 19kB ...
#     FUNVAL   (lat, lon) float64 19kB ...
# Attributes:
#     description:  Downscaling for 'ERA5' in the 'ITALY' area bounded by longi...
