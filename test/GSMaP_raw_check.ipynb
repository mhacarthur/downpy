# %%
import os
import glob
import numpy as np
import xarray as xr

import cartopy.feature as cfeature
import cartopy.crs as ccrs
import cartopy.feature as cf

from matplotlib import patches
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec

# %%
dir_base = os.path.join('/','media','arturo','T9','Data','Italy','Satellite')

# %%
list_file = glob.glob(os.path.join(dir_base, 'GSMaP', '1h', 'raw', '2005', '*.nc'))
list_file = sorted(list_file)
list_len = len(list_file)
print(f'Number of files: {list_len}')
# Out:
# Number of files: 8489

# %%
DATA = xr.open_dataset(list_file[0])
DATA
# Out:
# <xarray.Dataset> Size: 127kB
# Dimensions:           (lat: 120, lon: 130)
# Coordinates:
#     time              datetime64[ns] 8B ...
#   * lat               (lat) float64 960B 48.0 47.9 47.8 47.7 ... 36.2 36.1 36.0
#   * lon               (lon) float64 1kB 6.0 6.101 6.202 6.302 ... 18.8 18.9 19.0
# Data variables:
#     hourlyPrecipRate  (lat, lon) float64 125kB ...

# %%
print(DATA['hourlyPrecipRate'].attrs)
# Out:
# {}
