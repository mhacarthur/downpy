# %%
from datetime import datetime
import dask.array as da
import os
import time
import h5py
import numpy as np
import xarray as xr
import downscale as down

import cartopy
import cartopy.feature as cf
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

from matplotlib import patches
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = os.path.join('/','media','arturo','Arturo','Data','Italy','Satellite','IMERG','IMERG_Italy_1dy_2000_06_01_2024_02_29_veneto_R1.nc')
DATA = xr.open_dataset(data_dir)
DATA = DATA.sel(time=DATA.time.dt.year.isin([np.arange(2001,2005+1)]))

lons = DATA.lon.values
lats = DATA.lat.values

lon2d_ref, lat2d_ref = np.meshgrid(lons, lats)

nlon_ref = np.size(lons)
nlat_ref = np.size(lats)

dx = np.abs(lons[1] - lons[0])
dy = np.abs(lats[1] - lats[0])

ntime = len(DATA['time'])

DATA
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (time: 1826, lat: 19, lon: 25)
# Coordinates:
#   * time     (time) datetime64[ns] 15kB 2001-01-01 2001-01-02 ... 2005-12-31
#   * lat      (lat) float64 152B 44.85 44.95 45.05 45.15 ... 46.45 46.55 46.65
#   * lon      (lon) float32 100B 10.65 10.75 10.85 10.95 ... 12.85 12.95 13.05
# Data variables:
#     PRE      (time, lat, lon) float64 7MB ...
# Attributes:
#     description:  IMERG daily data for Italy region

# %%
lat_d = []
for i in range(0,nlat_ref-1):
    lat_tmp = lats[i] + ((lats[i+1] - lats[i])/2)
    lat_d.append(lat_tmp)

lon_d = []
for i in range(0,nlon_ref-2):
    lon_tmp = lons[i] + ((lons[i+1] - lons[i])/2)
    lon_d.append(lon_tmp)

lon2d_d, lat2d_d = np.meshgrid(lon_d, lat_d)
nlat = len(lat_d)
nlon = len(lon_d)

# %%
np.mean(DATA['PRE'].values,axis=0).shape
# Out:
# (19, 25)

# %%
cmap = plt.cm.Spectral_r
proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(4,4),dpi=300)
gs = gridspec.GridSpec(1,1)

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 0], projection = proj)
ax1.set_extent([10, 13.5, 44.5, 47], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
a1 = ax1.contourf(lon2d_ref, lat2d_ref, np.mean(DATA['PRE'].values,axis=0), cmap=cmap)
ax1.scatter(lon2d_ref, lat2d_ref, s=3, c='k')
ax1.scatter(lon2d_d, lat2d_d, s=1, c='r')

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

cbar = plt.colorbar(a1, fraction=0.033)
cbar.ax.tick_params(labelsize=5)

# %%
thresh = 1
acf = 'mar'
toll=0.005
opt_method='genetic'
# dt = 3
Tr = np.array([1, 2, 5, 10, 20, 50, 100])
nyears = len(Tr)

# %% [markdown]
# ## 309 minutos aprox

# %%
MEV_d_matrix = np.zeros([nyears, nlat, nlon])
MEV_s_matrix = np.zeros([nyears, nlat, nlon])
NYs_matrix = np.zeros([nlat, nlon])
CYs_matrix = np.zeros([nlat, nlon])
WYs_matrix = np.zeros([nlat, nlon])
NYd_matrix = np.zeros([nlat, nlon])
CYd_matrix = np.zeros([nlat, nlon])
WYd_matrix = np.zeros([nlat, nlon])
Nd_matrix = np.zeros([nlat, nlon])
Cd_matrix = np.zeros([nlat, nlon])
Wd_matrix = np.zeros([nlat, nlon])
Ns_matrix = np.zeros([nlat, nlon])
Cs_matrix = np.zeros([nlat, nlon])
Ws_matrix = np.zeros([nlat, nlon])
eps_s_matrix = np.zeros([nlat, nlon])
alp_s_matrix = np.zeros([nlat, nlon])
eps_d_matrix = np.zeros([nlat, nlon])
alp_d_matrix = np.zeros([nlat, nlon])
gam_d_matrix = np.zeros([nlat, nlon])
gam_s_matrix = np.zeros([nlat, nlon])
beta_matrix = np.zeros([nlat, nlon])
QUANTILE = np.zeros([ntime, nlat, nlon])
RAIN_D = np.zeros([ntime, nlat, nlon])

L0 = 0.005 # 0.5 degrees
npix = 3

count = 0
for i in range(nlat):
    for j in range(nlon):
        clat = lat2d_d[i,j]
        clon = lon2d_d[i,j]
        L1 = down.area_lat_long(clat, clon, dy, dx)[0] # in Km
        
        tmpalat = DATA['lat'][:]
        tmpalon = DATA['lon'][:]
        dates = DATA['time'][:]
        dset = np.swapaxes(DATA['PRE'],0,2).data[:,:,:]
        x = da.from_array(dset, chunks=(6, 6, 300))
        xrs0 = xr.DataArray(x,  coords={'lon':tmpalon, 'lat':tmpalat, 'time':dates},
                                                            dims=('lon', 'lat', 'time'))
        xrs = xrs0.where(xrs0 >= -0.001)

        buffer = 0.50*npix*dx
        eps = 1e-4 # to make sure to include boundaires -> add an eps buffer
        solat = clat - buffer + eps
        nolat = clat + buffer + eps
        ealon = clon + buffer + eps
        welon = clon - buffer + eps
        bcond = np.logical_and(
                    np.logical_and( xrs.lat > solat, xrs.lat < nolat),
                    np.logical_and( xrs.lon > welon, xrs.lon < ealon))

        box_3h = xrs.where(bcond, drop = True).load()
        
        downres = down.downscale(box_3h, Tr, thresh=thresh, L0=50, toll=toll,
                                acf=acf, save_yearly=True,
                                maxmiss=600, clat=clat, clon=clon,
                                opt_method=opt_method, plot=False)
        
        MEV_d_matrix[:,i,j] = downres['mev_d']
        MEV_s_matrix[:,i,j] = downres['mev_s']
        NYs_matrix[i,j] = downres['NYs'][0]
        CYs_matrix[i,j] = downres['CYs'][0]
        WYs_matrix[i,j] = downres['WYs'][0]
        NYd_matrix[i,j] = downres['NYd'][0]
        CYd_matrix[i,j] = downres['CYd'][0]
        WYd_matrix[i,j] = downres['WYd'][0]
        Nd_matrix[i,j] = downres['Nd']
        Cd_matrix[i,j] = downres['Cd']
        Wd_matrix[i,j] = downres['Wd']
        Ns_matrix[i,j] = downres['Ns']
        Cs_matrix[i,j] = downres['Cs']
        Ws_matrix[i,j] = downres['Ws']
        eps_s_matrix[i,j] =downres['eps_s'] 
        alp_s_matrix[i,j] = downres['alp_s']
        eps_d_matrix[i,j] = downres['eps_d']
        alp_d_matrix[i,j] = downres['alp_d']
        gam_d_matrix[i,j] = downres['gam_d']
        gam_s_matrix[i,j] = downres['gam_s']
        beta_matrix[i,j] = downres['beta']
        
        Ti = np.linspace(1,100,box_3h.shape[2])
        Fi = 1 - 1/Ti
        qq = down.mev_quant(Fi, 1, downres['Nd'], downres['Cd'], downres['Wd'], thresh=1)[0]
        QUANTILE[:,i,j] = qq/np.nanmax(qq)
        
        RAIN_D[:,i,j] = box_3h[1,1,:].data * qq/np.nanmax(qq)
        print()
# Out:
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002324844629168277
# differential_evolution step 2: f(x)= 0.00012256275155500423
# differential_evolution step 3: f(x)= 0.00011452746987708197
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00024637902939717764
# differential_evolution step 2: f(x)= 0.00024637902939717764
# differential_evolution step 3: f(x)= 0.00024637902939717764
# differential_evolution step 4: f(x)= 0.00023817667514515107
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00016397519642452225
# differential_evolution step 2: f(x)= 0.00016397519642452225
# differential_evolution step 3: f(x)= 0.00016397519642452225
# differential_evolution step 4: f(x)= 0.00016383048471319009
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00010979984761127268
# differential_evolution step 2: f(x)= 9.922758973305108e-05
# differential_evolution step 3: f(x)= 9.922758973305108e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00018559187621502342
# differential_evolution step 2: f(x)= 0.00018263603480803532
# differential_evolution step 3: f(x)= 0.00016591521763500178
# differential_evolution step 4: f(x)= 0.00016591521763500178
# differential_evolution step 5: f(x)= 0.00016584012931963996
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 8.057388936720784e-05
# differential_evolution step 2: f(x)= 7.920168847009581e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00021132548222016118
# differential_evolution step 2: f(x)= 0.00016758520139010367
# differential_evolution step 3: f(x)= 0.0001574514405001462
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00029461582940028876
# differential_evolution step 2: f(x)= 0.00029461582940028876
# differential_evolution step 3: f(x)= 0.00029461582940028876
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00025448507098207773
# differential_evolution step 2: f(x)= 0.00025239919441601025
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0007503733085097014
# differential_evolution step 2: f(x)= 0.0007503733085097014
# differential_evolution step 3: f(x)= 0.0007503733085097014
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003295324024076211
# differential_evolution step 2: f(x)= 0.0003295324024076211
# differential_evolution step 3: f(x)= 0.00032300314608288893
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00034713222190740987
# differential_evolution step 2: f(x)= 0.00034713222190740987
# differential_evolution step 3: f(x)= 0.00034713222190740987
# differential_evolution step 4: f(x)= 0.00034713222190740987
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00046064988376737643
# differential_evolution step 2: f(x)= 0.00046064988376737643
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0006257169631292002
# differential_evolution step 2: f(x)= 0.0006083107455535934
# differential_evolution step 3: f(x)= 0.0006083107455535934
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0006458730234013248
# differential_evolution step 2: f(x)= 0.0006458730234013248
# differential_evolution step 3: f(x)= 0.0006458730234013248
# differential_evolution step 4: f(x)= 0.0006458730234013248
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002848274136197269
# differential_evolution step 2: f(x)= 0.0002848274136197269
# differential_evolution step 3: f(x)= 0.00022336393087790945
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003062495885171171
# differential_evolution step 2: f(x)= 0.0003062495885171171
# differential_evolution step 3: f(x)= 0.0003062495885171171
# differential_evolution step 4: f(x)= 0.0003062495885171171
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.007927806297245696
# differential_evolution step 2: f(x)= 0.007927806297245696
# differential_evolution step 3: f(x)= 0.007471729589110263
# differential_evolution step 4: f(x)= 0.007471729589110263
# differential_evolution step 5: f(x)= 0.007471729589110263
# differential_evolution step 6: f(x)= 0.007471729589110263
# differential_evolution step 7: f(x)= 0.007471729589110263
# differential_evolution step 8: f(x)= 0.007471729589110263
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.03483962328812233
# differential_evolution step 2: f(x)= 0.03427702826532614
# differential_evolution step 3: f(x)= 0.03282879054874649
# differential_evolution step 4: f(x)= 0.03219002172915848
# differential_evolution step 5: f(x)= 0.03127233018580868
# differential_evolution step 6: f(x)= 0.031193517977023563
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.005098395956489064
# differential_evolution step 2: f(x)= 0.005098395956489064
# differential_evolution step 3: f(x)= 0.005098395956489064
# differential_evolution step 4: f(x)= 0.005098395956489064
# differential_evolution step 5: f(x)= 0.005098190339208153
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0016833929580922868
# differential_evolution step 2: f(x)= 0.0016661680693526347
# differential_evolution step 3: f(x)= 0.0016473302555291053
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0011840790482310337
# differential_evolution step 2: f(x)= 0.0011427903889725225
# differential_evolution step 3: f(x)= 0.0011427903889725225
# differential_evolution step 4: f(x)= 0.0011427903889725225
# differential_evolution step 5: f(x)= 0.0011427903889725225
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0007972753781697844
# differential_evolution step 2: f(x)= 0.0007972753781697844
# differential_evolution step 3: f(x)= 0.0007972753781697844
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004966930807924569
# differential_evolution step 2: f(x)= 0.0004966930807924569
# differential_evolution step 3: f(x)= 0.0004966930807924569
# differential_evolution step 4: f(x)= 0.0004966930807924569
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005477467202088227
# differential_evolution step 2: f(x)= 0.0005477467202088227
# differential_evolution step 3: f(x)= 0.0005431889021100895
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003402724975122524
# differential_evolution step 2: f(x)= 0.0003290462009663946
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00018308284950654372
# differential_evolution step 2: f(x)= 0.0001375053128006916
# differential_evolution step 3: f(x)= 7.505597071864569e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003231411563180536
# differential_evolution step 2: f(x)= 0.00021972912473084184
# differential_evolution step 3: f(x)= 0.00016064135167901956
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00018699381459839583
# differential_evolution step 2: f(x)= 0.00018699381459839583
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00013252756801225102
# differential_evolution step 2: f(x)= 0.00013252756801225102
# differential_evolution step 3: f(x)= 0.00011586001347263226
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005830100391800508
# differential_evolution step 2: f(x)= 0.0001931422634095518
# differential_evolution step 3: f(x)= 0.0001931422634095518
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004578154640639029
# differential_evolution step 2: f(x)= 0.0004578154640639029
# differential_evolution step 3: f(x)= 0.0004578154640639029
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.000534874183891073
# differential_evolution step 2: f(x)= 0.0005176258295715107
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004862131097236447
# differential_evolution step 2: f(x)= 0.0004435127050061643
# differential_evolution step 3: f(x)= 0.00043909731366078344
# differential_evolution step 4: f(x)= 0.0004386902229191585
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.000414977418292679
# differential_evolution step 2: f(x)= 0.000414977418292679
# differential_evolution step 3: f(x)= 0.000414977418292679
# differential_evolution step 4: f(x)= 0.000414977418292679
# differential_evolution step 5: f(x)= 0.000414977418292679
# differential_evolution step 6: f(x)= 0.000414977418292679
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00010645515362604995
# differential_evolution step 2: f(x)= 0.00010645515362604995
# differential_evolution step 3: f(x)= 9.109434871885154e-05
# differential_evolution step 4: f(x)= 9.109434871885154e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.000673647094895952
# differential_evolution step 2: f(x)= 0.000673647094895952
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005845218884552926
# differential_evolution step 2: f(x)= 0.0005845218884552926
# differential_evolution step 3: f(x)= 0.0005845218884552926
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004202301996295829
# differential_evolution step 2: f(x)= 0.0004202301996295829
# differential_evolution step 3: f(x)= 0.00041923130452152946
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0009202244789581337
# differential_evolution step 2: f(x)= 0.0008861330256719416
# differential_evolution step 3: f(x)= 0.0008861330256719416
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.011845432951376208
# differential_evolution step 2: f(x)= 0.011845432951376208
# differential_evolution step 3: f(x)= 0.011785093437819348
# differential_evolution step 4: f(x)= 0.011785093437819348
# differential_evolution step 5: f(x)= 0.011785093437819348
# differential_evolution step 6: f(x)= 0.011785036461665633
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.012796648962042929
# differential_evolution step 2: f(x)= 0.012796648962042929
# differential_evolution step 3: f(x)= 0.012796648962042929
# differential_evolution step 4: f(x)= 0.012796648962042929
# differential_evolution step 5: f(x)= 0.012796648962042929
# differential_evolution step 6: f(x)= 0.009317727374070212
# differential_evolution step 7: f(x)= 0.009317727374070212
# differential_evolution step 8: f(x)= 0.009317727374070212
# differential_evolution step 9: f(x)= 0.009317727374070212
# differential_evolution step 10: f(x)= 0.009317727374070212
# differential_evolution step 11: f(x)= 0.009317727374070212
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.003635735835862853
# differential_evolution step 2: f(x)= 0.003635735835862853
# differential_evolution step 3: f(x)= 0.003523704940466785
# differential_evolution step 4: f(x)= 0.003523704940466785
# differential_evolution step 5: f(x)= 0.003523704940466785
# differential_evolution step 6: f(x)= 0.003520859308082188
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0022296420337011924
# differential_evolution step 2: f(x)= 0.001559639431720151
# differential_evolution step 3: f(x)= 0.001559639431720151
# differential_evolution step 4: f(x)= 0.001559639431720151
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0012365790259899112
# differential_evolution step 2: f(x)= 0.0012365790259899112
# differential_evolution step 3: f(x)= 0.0012306885558307932
# differential_evolution step 4: f(x)= 0.0012306885558307932
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0012590263962380427
# differential_evolution step 2: f(x)= 0.0011714617073116547
# differential_evolution step 3: f(x)= 0.0011672687826715649
# differential_evolution step 4: f(x)= 0.0011672687826715649
# differential_evolution step 5: f(x)= 0.0011672687826715649
# differential_evolution step 6: f(x)= 0.0011671463384799019
# differential_evolution step 7: f(x)= 0.0011671463384799019
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00038375205871104396
# differential_evolution step 2: f(x)= 0.00038375205871104396
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005117746894407775
# differential_evolution step 2: f(x)= 0.0005117746894407775
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00016223078215805422
# differential_evolution step 2: f(x)= 0.00016223078215805422
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0001484393752573211
# differential_evolution step 2: f(x)= 0.0001400104913917298
# differential_evolution step 3: f(x)= 0.0001400104913917298
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003379949862788517
# differential_evolution step 2: f(x)= 0.0003355388956756136
# differential_evolution step 3: f(x)= 0.0003355388956756136
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002615698319838794
# differential_evolution step 2: f(x)= 0.0002615698319838794
# differential_evolution step 3: f(x)= 0.0002615698319838794
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00029736111576671506
# differential_evolution step 2: f(x)= 0.00029736111576671506
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002701277558491953
# differential_evolution step 2: f(x)= 0.0002701277558491953
# differential_evolution step 3: f(x)= 0.0002701277558491953
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0007502036106116714
# differential_evolution step 2: f(x)= 0.0007502036106116714
# differential_evolution step 3: f(x)= 0.0007502036106116714
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00023765871423002494
# differential_evolution step 2: f(x)= 0.00018026271887922193
# differential_evolution step 3: f(x)= 0.00017424306892334905
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00046271024484892496
# differential_evolution step 2: f(x)= 0.00045545554336258866
# differential_evolution step 3: f(x)= 0.00045545554336258866
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00047814293205368296
# differential_evolution step 2: f(x)= 0.0004760831199345449
# differential_evolution step 3: f(x)= 0.0004760831199345449
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004293777788632117
# differential_evolution step 2: f(x)= 0.0004293777788632117
# differential_evolution step 3: f(x)= 0.0004293777788632117
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003413863994726336
# differential_evolution step 2: f(x)= 0.0003413863994726336
# differential_evolution step 3: f(x)= 0.0003413863994726336
# differential_evolution step 4: f(x)= 0.0003413863994726336
# differential_evolution step 5: f(x)= 0.00034101974122569326
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00038840327971377596
# differential_evolution step 2: f(x)= 0.00036400060616049713
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0006798748771399834
# differential_evolution step 2: f(x)= 0.0006798748771399834
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0024574684276138818
# differential_evolution step 2: f(x)= 0.0024574684276138818
# differential_evolution step 3: f(x)= 0.0024574684276138818
# differential_evolution step 4: f(x)= 0.0024574684276138818
# differential_evolution step 5: f(x)= 0.0024574684276138818
# differential_evolution step 6: f(x)= 0.0024574684276138818
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.006595690325684353
# differential_evolution step 2: f(x)= 0.006595690325684353
# differential_evolution step 3: f(x)= 0.006424922697899123
# differential_evolution step 4: f(x)= 0.006424922697899123
# differential_evolution step 5: f(x)= 0.006271506639325552
# differential_evolution step 6: f(x)= 0.005156828607514673
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0013074034517727663
# differential_evolution step 2: f(x)= 0.0013074034517727663
# differential_evolution step 3: f(x)= 0.0012402278830069737
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00040590385456639426
# differential_evolution step 2: f(x)= 0.000304223256599764
# differential_evolution step 3: f(x)= 0.000304223256599764
# differential_evolution step 4: f(x)= 0.000304223256599764
# differential_evolution step 5: f(x)= 0.000304223256599764
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0015551102210387912
# differential_evolution step 2: f(x)= 0.0014117187872914366
# differential_evolution step 3: f(x)= 0.0014117187872914366
# differential_evolution step 4: f(x)= 0.0013721692037763824
# differential_evolution step 5: f(x)= 0.0013721692037763824
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0014473908485598645
# differential_evolution step 2: f(x)= 0.0014473908485598645
# differential_evolution step 3: f(x)= 0.0014473908485598645
# differential_evolution step 4: f(x)= 0.0014473908485598645
# differential_evolution step 5: f(x)= 0.0014473908485598645
# differential_evolution step 6: f(x)= 0.0014473908485598645
# differential_evolution step 7: f(x)= 0.0014473908485598645
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0019570715213724364
# differential_evolution step 2: f(x)= 0.0019570715213724364
# differential_evolution step 3: f(x)= 0.0019506906740487443
# differential_evolution step 4: f(x)= 0.0019498637397835595
# differential_evolution step 5: f(x)= 0.0019498637397835595
# differential_evolution step 6: f(x)= 0.0019449671752218007
# differential_evolution step 7: f(x)= 0.0019449671752218007
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005547315012540291
# differential_evolution step 2: f(x)= 0.0005547315012540291
# differential_evolution step 3: f(x)= 0.0005544581601966813
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0008970978478681975
# differential_evolution step 2: f(x)= 0.0008970978478681975
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00042554461495972163
# differential_evolution step 2: f(x)= 0.00042554461495972163
# differential_evolution step 3: f(x)= 0.00042554461495972163
# differential_evolution step 4: f(x)= 0.00042554461495972163
# differential_evolution step 5: f(x)= 0.00042554461495972163
# differential_evolution step 6: f(x)= 0.00042554461495972163
# differential_evolution step 7: f(x)= 0.00042554461495972163
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002994994115988914
# differential_evolution step 2: f(x)= 0.0002967599147843042
# differential_evolution step 3: f(x)= 0.0002967599147843042
# differential_evolution step 4: f(x)= 0.00028954539192594785
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002907390528369299
# differential_evolution step 2: f(x)= 0.00028608437409501363
# differential_evolution step 3: f(x)= 0.0002831274294808742
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00044923346820389905
# differential_evolution step 2: f(x)= 0.00044923346820389905
# differential_evolution step 3: f(x)= 0.0004427090881227952
# differential_evolution step 4: f(x)= 0.00044077779845104297
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003433318092570402
# differential_evolution step 2: f(x)= 0.0003433318092570402
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00045469093864715
# differential_evolution step 2: f(x)= 0.00045469093864715
# differential_evolution step 3: f(x)= 0.00045469093864715
# differential_evolution step 4: f(x)= 0.00045381528619349305
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 9.3649185700456e-05
# differential_evolution step 2: f(x)= 9.3649185700456e-05
# differential_evolution step 3: f(x)= 9.3649185700456e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 4.365737090097255e-05
# differential_evolution step 2: f(x)= 3.043638424386315e-05
# differential_evolution step 3: f(x)= 2.9271437873270572e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00019326602933032315
# differential_evolution step 2: f(x)= 0.00019326602933032315
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00018736792400032094
# differential_evolution step 2: f(x)= 0.00018736792400032094
# differential_evolution step 3: f(x)= 0.00018582385869297873
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00013126285657825824
# differential_evolution step 2: f(x)= 0.00013126285657825824
# differential_evolution step 3: f(x)= 0.00013126285657825824
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00011284899056301027
# differential_evolution step 2: f(x)= 0.00011284899056301027
# differential_evolution step 3: f(x)= 9.220104805275578e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0002924444747965656
# differential_evolution step 2: f(x)= 0.00029158644070293783
# differential_evolution step 3: f(x)= 0.00029071251609658554
# differential_evolution step 4: f(x)= 0.00029071251609658554
# differential_evolution step 5: f(x)= 0.00029071251609658554
# differential_evolution step 6: f(x)= 0.0002901129475631515
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004955531056828211
# differential_evolution step 2: f(x)= 0.0004447532362480207
# differential_evolution step 3: f(x)= 0.0004447532362480207
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005717534471761492
# differential_evolution step 2: f(x)= 0.0005717534471761492
# differential_evolution step 3: f(x)= 0.0005717534471761492
# differential_evolution step 4: f(x)= 0.0005717534471761492
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0018103137640733246
# differential_evolution step 2: f(x)= 0.001506573887329866
# differential_evolution step 3: f(x)= 0.001506573887329866
# differential_evolution step 4: f(x)= 0.001506573887329866
# differential_evolution step 5: f(x)= 0.001506573887329866
# differential_evolution step 6: f(x)= 0.001506573887329866
# differential_evolution step 7: f(x)= 0.001506573887329866
# differential_evolution step 8: f(x)= 0.001506573887329866
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00111918315287081
# differential_evolution step 2: f(x)= 0.0009006074457032087
# differential_evolution step 3: f(x)= 0.000889954078385759
# differential_evolution step 4: f(x)= 0.000889954078385759
# differential_evolution step 5: f(x)= 0.000889954078385759
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005942770160396944
# differential_evolution step 2: f(x)= 0.0005299057631491419
# differential_evolution step 3: f(x)= 0.0005257424641479932
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003145814248767944
# differential_evolution step 2: f(x)= 0.00019029754203629738
# differential_evolution step 3: f(x)= 0.00019029754203629738
# differential_evolution step 4: f(x)= 0.00018909444151360102
# differential_evolution step 5: f(x)= 0.00018909444151360102
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0015560537704635527
# differential_evolution step 2: f(x)= 0.0015560537704635527
# differential_evolution step 3: f(x)= 0.0015421829393107334
# differential_evolution step 4: f(x)= 0.0015406243877718012
# differential_evolution step 5: f(x)= 0.0015406243877718012
# differential_evolution step 6: f(x)= 0.0015406243877718012
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0010846531466938765
# differential_evolution step 2: f(x)= 0.0010759906044763101
# differential_evolution step 3: f(x)= 0.0010759906044763101
# differential_evolution step 4: f(x)= 0.0010759906044763101
# differential_evolution step 5: f(x)= 0.0010650335873561342
# differential_evolution step 6: f(x)= 0.0010650335873561342
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.000500632528697814
# differential_evolution step 2: f(x)= 0.0004653103028940464
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.000901793900167829
# differential_evolution step 2: f(x)= 0.000901793900167829
# differential_evolution step 3: f(x)= 0.0008911961918743789
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0005700824769987173
# differential_evolution step 2: f(x)= 0.0005696978946805311
# differential_evolution step 3: f(x)= 0.0005696978946805311
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0007537010520646123
# differential_evolution step 2: f(x)= 0.0007537010520646123
# differential_evolution step 3: f(x)= 0.0007537010520646123
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0006234875135823962
# differential_evolution step 2: f(x)= 0.0006056225659043376
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0003263396616973278
# differential_evolution step 2: f(x)= 0.0003263396616973278
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Taylor_Beta WARNING: not enough accuracy!
# the time resolution of the coarse data might not be enough!
# or try to increase the value of interp
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 5.8823835785345164e-05
# differential_evolution step 2: f(x)= 5.8823835785345164e-05
# differential_evolution step 3: f(x)= 5.7726321550932917e-05
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# mevd_quant:: ERROR - fsolve does not work -  change x0
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00044632657013707035
# differential_evolution step 2: f(x)= 0.0004429979861001351
# differential_evolution step 3: f(x)= 0.0004429979861001351
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 9.107365798830188e-05
# ...
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0024963573416549273
# differential_evolution step 2: f(x)= 0.0024963573416549273
# differential_evolution step 3: f(x)= 0.002481588876695336
# differential_evolution step 4: f(x)= 0.002481588876695336
# differential_evolution step 5: f(x)= 0.002481588876695336
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0008824471167403784
# differential_evolution step 2: f(x)= 0.0008824471167403784
# differential_evolution step 3: f(x)= 0.0008824471167403784
# differential_evolution step 4: f(x)= 0.0008704990171815376
# differential_evolution step 5: f(x)= 0.0008598297892740031
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.001518073727588761
# differential_evolution step 2: f(x)= 0.0014979162536798505
# differential_evolution step 3: f(x)= 0.0014979162536798505
# differential_evolution step 4: f(x)= 0.0014979162536798505
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0018640044450039255
# differential_evolution step 2: f(x)= 0.0018640044450039255
# differential_evolution step 3: f(x)= 0.0013039347443665633
# differential_evolution step 4: f(x)= 0.0013039347443665633
# differential_evolution step 5: f(x)= 0.0013039347443665633
# differential_evolution step 6: f(x)= 0.0013039347443665633
# differential_evolution step 7: f(x)= 0.0013039347443665633
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0029062219162907725
# differential_evolution step 2: f(x)= 0.0020259082355180624
# differential_evolution step 3: f(x)= 0.0020259082355180624
# differential_evolution step 4: f(x)= 0.0020259082355180624
# differential_evolution step 5: f(x)= 0.0012649125312258883
# differential_evolution step 6: f(x)= 0.0012649125312258883
# differential_evolution step 7: f(x)= 0.0012649125312258883
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0008040545247226995
# differential_evolution step 2: f(x)= 0.0007858009896077659
# differential_evolution step 3: f(x)= 0.0007858009896077659
# differential_evolution step 4: f(x)= 0.0007858009896077659
# differential_evolution step 5: f(x)= 0.0007858009896077659
# differential_evolution step 6: f(x)= 0.0007858009896077659
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0017417031548065055
# differential_evolution step 2: f(x)= 0.0017417031548065055
# differential_evolution step 3: f(x)= 0.0017385348184495804
# differential_evolution step 4: f(x)= 0.0017385348184495804
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0020885721899500725
# differential_evolution step 2: f(x)= 0.0020885721899500725
# differential_evolution step 3: f(x)= 0.002057490936873878
# differential_evolution step 4: f(x)= 0.0020518771506243304
# differential_evolution step 5: f(x)= 0.002050498339252334
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0014927362423528732
# differential_evolution step 2: f(x)= 0.0014927362423528732
# differential_evolution step 3: f(x)= 0.0014927362423528732
# differential_evolution step 4: f(x)= 0.0014926085648053718
# differential_evolution step 5: f(x)= 0.0014885906072919955
# differential_evolution step 6: f(x)= 0.0014885906072919955
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.008914976147396784
# differential_evolution step 2: f(x)= 0.008914976147396784
# differential_evolution step 3: f(x)= 0.00651366514943878
# differential_evolution step 4: f(x)= 0.006500159765494339
# differential_evolution step 5: f(x)= 0.006272696543962064
# differential_evolution step 6: f(x)= 0.006272696543962064
# differential_evolution step 7: f(x)= 0.006262347066908722
# differential_evolution step 8: f(x)= 0.006262347066908722
# differential_evolution step 9: f(x)= 0.0059466868413448086
# differential_evolution step 10: f(x)= 0.0059466868413448086
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0020105675870622543
# differential_evolution step 2: f(x)= 0.0020105675870622543
# differential_evolution step 3: f(x)= 0.0020105675870622543
# differential_evolution step 4: f(x)= 0.0020105675870622543
# differential_evolution step 5: f(x)= 0.002003203616731484
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00096466558705094
# differential_evolution step 2: f(x)= 0.0009268013708695142
# differential_evolution step 3: f(x)= 0.0009268013708695142
# differential_evolution step 4: f(x)= 0.0009268013708695142
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0021321051185942156
# differential_evolution step 2: f(x)= 0.0018950512561555426
# differential_evolution step 3: f(x)= 0.0018694887838515192
# differential_evolution step 4: f(x)= 0.0018694887838515192
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.002099334556810179
# differential_evolution step 2: f(x)= 0.0012539381890508674
# differential_evolution step 3: f(x)= 0.0012539381890508674
# differential_evolution step 4: f(x)= 0.0008905748555530398
# differential_evolution step 5: f(x)= 0.0008905748555530398
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004875903414490684
# differential_evolution step 2: f(x)= 0.0004543877436922386
# differential_evolution step 3: f(x)= 0.00044207646724449636
# differential_evolution step 4: f(x)= 0.00044207646724449636
# differential_evolution step 5: f(x)= 0.00044207646724449636
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0009053065554510659
# differential_evolution step 2: f(x)= 0.0009053065554510659
# differential_evolution step 3: f(x)= 0.0009053065554510659
# differential_evolution step 4: f(x)= 0.0009053065554510659
# differential_evolution step 5: f(x)= 0.0009052970763157531
# differential_evolution step 6: f(x)= 0.0009052970763157531
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0011943318954530466
# differential_evolution step 2: f(x)= 0.0011538932967732085
# differential_evolution step 3: f(x)= 0.0011384859194346801
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.00038941395332679833
# differential_evolution step 2: f(x)= 0.00032340117373398343
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0006980040657364286
# differential_evolution step 2: f(x)= 0.0006668801393455206
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0016421255378746872
# differential_evolution step 2: f(x)= 0.0013356645395389158
# differential_evolution step 3: f(x)= 0.0011928484617122178
# differential_evolution step 4: f(x)= 0.0011928484617122178
# differential_evolution step 5: f(x)= 0.0011928484617122178
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.002533946505807525
# differential_evolution step 2: f(x)= 0.00247621382703831
# differential_evolution step 3: f(x)= 0.00247621382703831
# differential_evolution step 4: f(x)= 0.0024532471273519723
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0017908295423350337
# differential_evolution step 2: f(x)= 0.0017908295423350337
# differential_evolution step 3: f(x)= 0.0017908295423350337
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.002246887492262045
# differential_evolution step 2: f(x)= 0.002246887492262045
# differential_evolution step 3: f(x)= 0.002246887492262045
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0032482955025897233
# differential_evolution step 2: f(x)= 0.0032482302760371002
# differential_evolution step 3: f(x)= 0.0032482302760371002
# differential_evolution step 4: f(x)= 0.0032452000496484943
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0022006870947452032
# differential_evolution step 2: f(x)= 0.0022006870947452032
# differential_evolution step 3: f(x)= 0.002173595667853613
# differential_evolution step 4: f(x)= 0.002173595667853613
# differential_evolution step 5: f(x)= 0.002173595667853613
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0024652592584809532
# differential_evolution step 2: f(x)= 0.00244873680166484
# differential_evolution step 3: f(x)= 0.00244873680166484
# differential_evolution step 4: f(x)= 0.00244873680166484
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0027054603294762143
# differential_evolution step 2: f(x)= 0.0027054603294762143
# differential_evolution step 3: f(x)= 0.0025438030995375213
# differential_evolution step 4: f(x)= 0.0025438030995375213
# differential_evolution step 5: f(x)= 0.0025438030995375213
# differential_evolution step 6: f(x)= 0.0025303825936902054
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0021197137022178326
# differential_evolution step 2: f(x)= 0.0021179790091452296
# differential_evolution step 3: f(x)= 0.0021179790091452296
# differential_evolution step 4: f(x)= 0.0021178933707189157
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0004798886203145105
# differential_evolution step 2: f(x)= 0.0004798886203145105
# differential_evolution step 3: f(x)= 0.0004798886203145105
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0018302210339588214
# differential_evolution step 2: f(x)= 0.0018302210339588214
# differential_evolution step 3: f(x)= 0.0018302210339588214
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.0016886294702741873
# differential_evolution step 2: f(x)= 0.0016852011205739782
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters
# downscale warning: box sizes are not equal
# Downscaling Intermittency
# Downscaling the correlation
# Computing the correlation
# differential_evolution step 1: f(x)= 0.001832216311493069
# differential_evolution step 2: f(x)= 0.0017997628086854813
# Polishing solution with 'L-BFGS-B'
# Downscaling pdf - global Weibull parameters
# Downscaling pdf - yearly Weibull parameters

# %%
downres['NYs']
# Out:
# array([148., 165., 128.])

# %%
DOWN_xr = xr.Dataset(data_vars={
                "MEV_d": (("year","lat","lon"), MEV_d_matrix),
                "MEV_s": (("year","lat","lon"), MEV_s_matrix),
                "NYs": (("lat","lon"),NYs_matrix ),
                "CYs": (("lat","lon"),CYs_matrix ),
                "WYs": (("lat","lon"),WYs_matrix ),
                "NYd": (("lat","lon"),NYd_matrix ),
                "CYd": (("lat","lon"),CYd_matrix ),
                "WYd": (("lat","lon"),WYd_matrix ),
                "Nd": (("lat","lon"),Nd_matrix ),
                "Cd": (("lat","lon"),Cd_matrix ),
                "Wd": (("lat","lon"),Wd_matrix ),
                "Ns": (("lat","lon"),Ns_matrix ),
                "Cs": (("lat","lon"),Cs_matrix ),
                "Ws": (("lat","lon"),Ws_matrix ),
                "eps_s": (("lat","lon"),eps_s_matrix ),
                "alp_s": (("lat","lon"),alp_s_matrix ),
                "eps_d": (("lat","lon"),eps_d_matrix ),
                "alp_d": (("lat","lon"),alp_d_matrix ),
                
                "gam_d": (("lat","lon"),gam_d_matrix ),
                "gam_s": (("lat","lon"),gam_s_matrix ),
                "bet": (("lat","lon"),beta_matrix ),
                
                "Fi": (("time"),Fi ),
                "QUANTILE": (("time","lat","lon"),QUANTILE ),
                "RAIN_D": (("time","lat","lon"),RAIN_D ),
                },
                    coords={'year': Tr, 'time': DATA['time'],'lat': lat_d, 'lon': lon_d},
                    attrs=dict(description="Dowscalling test"))

DOWN_xr.MEV_d.attrs["standard_name"] = "Single quantile, or array of quantiles downscale Weibull parameters"
DOWN_xr.MEV_s.attrs["standard_name"] = "Single quantile, or array of quantiles global Weibull parameters"

DOWN_xr.NYs.attrs["standard_name"] = "Dimension parameter of Yearly MEV distribution"
DOWN_xr.CYs.attrs["standard_name"] = "Scale parameter of Yearly MEV distribution"
DOWN_xr.WYs.attrs["standard_name"] = "Shape parameter of Yearly MEV distribution"

DOWN_xr.NYd.attrs["standard_name"] = "Dimension parameter of downscale Yearly MEV distribution"
DOWN_xr.CYd.attrs["standard_name"] = "Scale parameter of downscale Yearly MEV distribution"
DOWN_xr.WYd.attrs["standard_name"] = "Shape parameter of downscale Yearly MEV distribution"

DOWN_xr.Nd.attrs["standard_name"] = "Dimension parameter of downscale global MEV distribution"
DOWN_xr.Cd.attrs["standard_name"] = "Scale parameter of downscale global MEV distribution"
DOWN_xr.Wd.attrs["standard_name"] = "Shape parameter of downscale global MEV distribution"

DOWN_xr.Ns.attrs["standard_name"] = "Dimension parameter of global MEV distribution"
DOWN_xr.Cs.attrs["standard_name"] = "Scale parameter of global MEV distribution"
DOWN_xr.Ws.attrs["standard_name"] = "Shape parameter of global MEV distribution"

DOWN_xr.eps_s.attrs["standard_name"] = "parameters of the correlation function at the pixel scale (d0_s)"
DOWN_xr.alp_s.attrs["standard_name"] = "parameters of the correlation function at the pixel scale (mu0_s)"

DOWN_xr.eps_d.attrs["standard_name"] = "parameters of the correlation function downscaled at scale L0 (d0_d)"
DOWN_xr.alp_d.attrs["standard_name"] = "parameters of the correlation function downscaled at scale L0 (mu0_d)"

DOWN_xr.gam_d.attrs["standard_name"] = "variance reduction function global"
DOWN_xr.gam_s.attrs["standard_name"] = "variance reduction function downscale"
DOWN_xr.bet.attrs["standard_name"] = "wet fraction reduction function between the two scale"

DOWN_xr.Fi.attrs["units"] = "Non exceedance probability"
DOWN_xr.QUANTILE.attrs["long_name"] = "Single quantile, or array of quantiles"
DOWN_xr.RAIN_D.attrs["long_name"] = "The product of QUANTILES and nearest rainfall series"

DOWN_xr.lat.attrs["units"] = "degrees_north"
DOWN_xr.lat.attrs["long_name"] = "Latitude"

DOWN_xr.lon.attrs["units"] = "degrees_east"
DOWN_xr.lon.attrs["long_name"] = "Longitude"

# %%
DOWN_xr
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:   (year: 7, lat: 18, lon: 23, time: 1095)
# Coordinates:
#   * time      (time) datetime64[ns] 9kB 2001-01-01 2001-01-02 ... 2003-12-31
#   * year      (year) int64 56B 1 2 5 10 20 50 100
#   * lat       (lat) float64 144B 44.9 45.0 45.1 45.2 ... 46.3 46.4 46.5 46.6
#   * lon       (lon) float64 184B 10.7 10.8 10.9 11.0 ... 12.6 12.7 12.8 12.9
# Data variables: (12/24)
#     MEV_d     (year, lat, lon) float64 23kB 1.131 1.093 61.27 ... 177.0 189.5
#     MEV_s     (year, lat, lon) float64 23kB 1.09 1.096 1.085 ... 190.9 206.0
#     NYs       (lat, lon) float64 3kB 107.0 103.0 104.0 ... 151.0 158.0 148.0
#     CYs       (lat, lon) float64 3kB 4.98 5.212 5.457 5.797 ... 5.62 5.786 5.714
#     WYs       (lat, lon) float64 3kB 0.6716 0.6808 0.7112 ... 0.7689 0.7322
#     NYd       (lat, lon) float64 3kB 114.0 108.0 107.0 ... 194.0 204.0 186.0
#     ...        ...
#     gam_d     (lat, lon) float64 3kB 1.155 1.147 1.132 ... 1.192 1.19 1.181
#     gam_s     (lat, lon) float64 3kB 1.116 1.111 1.099 1.092 ... 1.14 1.136 1.13
#     bet       (lat, lon) float64 3kB 0.9359 0.9563 0.9723 ... 0.7728 0.7965
#     Fi        (time) float64 9kB 0.0 0.08298 0.1533 0.2135 ... 0.99 0.99 0.99
#     QUANTILE  (time, lat, lon) float64 4MB 0.01097 0.01125 0.01189 ... 1.0 1.0
#     RAIN_D    (time, lat, lon) float64 4MB 0.002412 0.001912 ... 5.05 1.205
# Attributes:
#     description:  Dowscalling test

# %%
DOWN_out = os.path.join('..','data','down_test',f'VENETO_DOWN_PARAMETERS_2001_2003_3h.nc')
print(f'Export PRE data to {DOWN_out}')
DOWN_xr.to_netcdf(DOWN_out)
# Out:
# Export PRE data to ../data/down_test/VENETO_DOWN_PARAMETERS_2001_2003_3h.nc

# %%
lon2d, lat2d = np.meshgrid(DOWN_xr['lon'], DOWN_xr['lat'])

# %%
cmap = plt.cm.Spectral_r
proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(6,5),dpi=300)
gs = gridspec.GridSpec(1,3)

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 0], projection = proj)
# ax1.set_extent([-94, -90, 31, 34], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.contourf(lon2d,  lat2d, DOWN_xr.Nd, cmap=cmap)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 1], projection = proj)
# ax1.set_extent([-94, -90, 31, 34], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.contourf(lon2d,  lat2d, DOWN_xr.Cs, cmap=cmap)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 2], projection = proj)
# ax1.set_extent([-94, -90, 31, 34], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
ax1.contourf(lon2d,  lat2d, DOWN_xr.Wd, cmap=cmap)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

# %%
cmap = plt.cm.Spectral_r
proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(5,5),dpi=300)
gs = gridspec.GridSpec(1,2)

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 0], projection = proj)
# ax1.set_extent([-94, -90, 31, 34], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
a1 = ax1.contourf(lon2d,  lat2d, np.nanmean(RAIN_D,axis=0), cmap=cmap)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

cbar = plt.colorbar(a1, fraction=0.034)
cbar.ax.tick_params(labelsize=4)

# ============================================================================================================================
ax1 = plt.subplot(gs[0, 1], projection = proj)
# ax1.set_extent([-94, -90, 31, 34], crs=proj)
ax1.add_feature(cf.COASTLINE,linewidth=0.1, linestyle='-',edgecolor='k')
a1 = ax1.contourf(lon2d_ref, lat2d_ref, np.mean(DATA['PRE'].values,axis=0), cmap=cmap)

gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='gray',alpha=0.5,linestyle='--')
gl.top_labels = False
gl.bottom_labels = True
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 5, 'color': 'k'}
gl.ylabel_style = {'size': 5, 'color': 'k'}

cbar = plt.colorbar(a1, fraction=0.034)
cbar.ax.tick_params(labelsize=4)
